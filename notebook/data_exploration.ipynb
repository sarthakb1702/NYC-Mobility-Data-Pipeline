# %%
import sys
print(sys.executable)
# Out:
# e:\Projects\NYC Mobility Data Engineering & Analytics Platform\.venv-1\Scripts\python.exe

# %%
import pandas as pd

# %%
file = r"E:\Projects\NYC Mobility Data Engineering & Analytics Platform\data\yellow_trip\yellow_tripdata_2024-01.parquet"

df = pd.read_parquet(file)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2964624 entries, 0 to 2964623
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.isnull().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          140162
# trip_distance                 0
# RatecodeID               140162
# store_and_fwd_flag       140162
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge     140162
# Airport_fee              140162
# dtype: int64

# %%
import glob

files = glob.glob(
    r"E:\Projects\NYC Mobility Data Engineering & Analytics Platform\data\yellow_trip\*.parquet"
)

for file in files:
    df_temp = pd.read_parquet(file, engine="pyarrow")
    print(file.split("\\")[-1], "→", len(df_temp), "rows,", len(df_temp.columns), "columns")
# Out:
# yellow_tripdata_2024-01.parquet → 2964624 rows, 19 columns
# yellow_tripdata_2024-02.parquet → 3007526 rows, 19 columns
# yellow_tripdata_2024-03.parquet → 3582628 rows, 19 columns
# yellow_tripdata_2024-04.parquet → 3514289 rows, 19 columns
# yellow_tripdata_2024-05.parquet → 3723833 rows, 19 columns
# yellow_tripdata_2024-06.parquet → 3539193 rows, 19 columns
# yellow_tripdata_2024-07.parquet → 3076903 rows, 19 columns
# yellow_tripdata_2024-08.parquet → 2979183 rows, 19 columns
# yellow_tripdata_2024-09.parquet → 3633030 rows, 19 columns
# yellow_tripdata_2024-10.parquet → 3833771 rows, 19 columns
# yellow_tripdata_2024-11.parquet → 3646369 rows, 19 columns
# yellow_tripdata_2024-12.parquet → 3668371 rows, 19 columns
# yellow_tripdata_2025-01.parquet → 3475226 rows, 20 columns
# yellow_tripdata_2025-02.parquet → 3577543 rows, 20 columns
# yellow_tripdata_2025-03.parquet → 4145257 rows, 20 columns
# yellow_tripdata_2025-04.parquet → 3970553 rows, 20 columns
# ...

# %%
df_2024 = pd.read_parquet(
    r"E:\Projects\NYC Mobility Data Engineering & Analytics Platform\data\yellow_trip\yellow_tripdata_2024-01.parquet"
)

df_2025 = pd.read_parquet(
    r"E:\Projects\NYC Mobility Data Engineering & Analytics Platform\data\yellow_trip\yellow_tripdata_2025-01.parquet"
)

print("New columns in 2025:")
print(set(df_2025.columns) - set(df_2024.columns))
# Out:
# New columns in 2025:
# {'cbd_congestion_fee'}

# %%
print(df_2025["cbd_congestion_fee"].describe())
print("\nNULL values:", df_2025["cbd_congestion_fee"].isna().sum())
print("\nUnique values:")
print("\n")
print(df_2025["cbd_congestion_fee"].value_counts(dropna=False))
# Out:
# count    3.475226e+06
# mean     4.834093e-01
# std      3.619307e-01
# min     -7.500000e-01
# 25%      0.000000e+00
# 50%      7.500000e-01
# 75%      7.500000e-01
# max      7.500000e-01
# Name: cbd_congestion_fee, dtype: float64
#
# NULL values: 0
#
# Unique values:
#
#
# cbd_congestion_fee
#  0.75    2246495
#  0.00    1222178
# -0.75       6553
# Name: count, dtype: int64

# %%
for year in [2024, 2025, 2026]:
    file = rf"E:\Projects\NYC Mobility Data Engineering & Analytics Platform\data\yellow_trip\yellow_tripdata_{year}-01.parquet"
    df_temp = pd.read_parquet(file)

    print(f"\n{year}:")
    print(df_temp.columns.tolist())
# Out:
# 2024:
# ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'Airport_fee']
#
# 2025:
# ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'Airport_fee', 'cbd_congestion_fee']
#
# 2026:
# ...
